# %% [markdown]
# # Data aggregation for visualization
#
# * [Load data](#Load-data)
# * [Aggregation by race](#Aggregation-by-race)
# * [Aggregation by name](#Aggregation-by-name)

# %% [markdown]
# ## Load data

# %%
import pandas as pd

# %%
# It's a bit long but you can load a remote CSV file from its URL !!! :fire:
raw_df = pd.read_csv('https://www.dropbox.com/s/tt9z5bik6uqndbz/full_database.csv?dl=1')

# %%
raw_df.shape
# Out:
# (1281195, 12)

# %%
raw_df.head()
# Out:
#                             Race             Date   Distance  \
# 0  Jungfrau-Marathon, Interlaken  sam. 06.09.2003  42.195000
# 1  Jungfrau-Marathon, Interlaken  sam. 06.09.2003  42.195000
# 2  Jungfrau-Marathon, Interlaken  sam. 06.09.2003  42.195000
# 3  Jungfrau-Marathon, Interlaken  sam. 06.09.2003  42.328675
# 4  Jungfrau-Marathon, Interlaken  sam. 06.09.2003  42.195000
#
#                 Name Sex  Year        LivingPlace  Rank       Time      Delay  \
# 0  Abächerli Walter    M  1952             Hinwil    47  4:31.56,1   0:53.5,3
# 1    Abbringh Ellen    F  1962   NL-Doorn 3941 EB    91   5:55.9,4  2:12.11,6
# 2     Abegglen Eddy    M  1954             Mürren   424  5:45.21,9  2:20.33,8
# 3      Abosa Emebet    F  1974               Zuoz     1  3:21.46,1      False
# 4  Abplanalp Michel    M  1960          Auvernier   143  4:30.26,9   1:7.35,3
#
#        Pace  len_name
# 0  0:6.26,0         2
# 1  0:8.25,0         2
# 2  0:8.11,0         2
# 3  0:4.46,0         2
# 4  0:6.24,0         2

# %% [markdown]
# ## Extra info

# %%
races_info = pd.read_csv('../datasets/races-information.csv',index_col=0).drop('url', axis=1)
races_info.head()
# Out:
#               date                     name   location  min_temp  max_temp  \
# 0  sam. 27.03.1999    Männedörfler Waldlauf  Männedorf       NaN       NaN
# 1  sam. 20.03.1999              Kerzerslauf    Kerzers       NaN       NaN
# 2  sam. 24.04.1999       Luzerner Stadtlauf     Luzern       NaN       NaN
# 3  sam. 24.04.1999         20km de Lausanne   Lausanne       NaN       NaN
# 4  sam. 24.04.1999  Chäsitzerlouf, Kehrsatz   Kehrsatz       NaN       NaN
#
#    uv_index weather_desc           latitude  longitude   weekday  day  month  \
# 0       NaN          NaN         47.2574625  8.6946733  saturday   27      3
# 1       NaN          NaN  46.97488999999999  7.1954365  saturday   20      3
# 2       NaN          NaN  47.05016819999999  8.3093072  saturday   24      4
# 3       NaN          NaN         46.5196535  6.6322734  saturday   24      4
# 4       NaN          NaN                NaN        NaN  saturday   24      4
#
#    year
# 0  1999
# 1  1999
# 2  1999
# 3  1999
# 4  1999

# %%
df = pd.merge(raw_df, races_info, how='left', left_on=['Race','Date'], right_on=['name','date']).drop(['date','name','location'],axis=1)
print(df.shape)
df.head()
# Out:
# (1281195, 22)
#                             Race             Date   Distance  \
# 0  Jungfrau-Marathon, Interlaken  sam. 06.09.2003  42.195000
# 1  Jungfrau-Marathon, Interlaken  sam. 06.09.2003  42.195000
# 2  Jungfrau-Marathon, Interlaken  sam. 06.09.2003  42.195000
# 3  Jungfrau-Marathon, Interlaken  sam. 06.09.2003  42.328675
# 4  Jungfrau-Marathon, Interlaken  sam. 06.09.2003  42.195000
#
#                 Name Sex  Year        LivingPlace  Rank       Time      Delay  \
# 0  Abächerli Walter    M  1952             Hinwil    47  4:31.56,1   0:53.5,3
# 1    Abbringh Ellen    F  1962   NL-Doorn 3941 EB    91   5:55.9,4  2:12.11,6
# 2     Abegglen Eddy    M  1954             Mürren   424  5:45.21,9  2:20.33,8
# 3      Abosa Emebet    F  1974               Zuoz     1  3:21.46,1      False
# 4  Abplanalp Michel    M  1960          Auvernier   143  4:30.26,9   1:7.35,3
#
#     ...   min_temp  max_temp  uv_index  weather_desc  latitude longitude  \
# 0   ...        NaN       NaN       NaN           NaN       NaN       NaN
# 1   ...        NaN       NaN       NaN           NaN       NaN       NaN
# 2   ...        NaN       NaN       NaN           NaN       NaN       NaN
# 3   ...        NaN       NaN       NaN           NaN       NaN       NaN
# 4   ...        NaN       NaN       NaN           NaN       NaN       NaN
#
#     weekday  day month    year
# 0  saturday  6.0   9.0  2003.0
# 1  saturday  6.0   9.0  2003.0
# 2  saturday  6.0   9.0  2003.0
# 3  saturday  6.0   9.0  2003.0
# 4  saturday  6.0   9.0  2003.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Convert some stuff

# %%
df.latitude = df.latitude.apply(float)
df.longitude = df.longitude.apply(float)

# %% [markdown]
# ## Clean race names

# %%
def clean_name(x):
    return x.replace("/"," ").replace("\\"," ")

df.Race = df.Race.apply(clean_name)

# %% [markdown]
# ## Convert time string to seconds (ignore further precision)

# %%
def time_to_seconds(x):
    # Get hours
    split = x.split(':')
    hours = int(split[0])
    # Get minutes
    split = split[1].split('.')
    minutes = int(split[0])
    # Get seconds
    split = split[1].split(',')
    seconds = int(split[0])
    return hours*3600 + minutes*60 + seconds

def seconds_to_time(x):
    minutes, seconds = divmod(x, 60)
    hours, minutes = divmod(minutes, 60)
    return '{}:{}:{}'.format(hours, minutes, seconds)

# %%
df['time'] = df.Time.apply(time_to_seconds)

# %% [markdown]
# ## Add a race+date index

# %%
df['race_index'] = df.Race + ' ; ' + df.Date

# %% [markdown]
# ## Final global dataframe

# %%
df.tail()
# Out:
#                                  Race             Date  Distance  \
# 1281190  Course de l'Escalade, Genève  sam. 05.12.2015  7.334317
# 1281191  Course de l'Escalade, Genève  sam. 05.12.2015  7.323638
# 1281192  Course de l'Escalade, Genève  sam. 05.12.2015  7.325498
# 1281193  Course de l'Escalade, Genève  sam. 05.12.2015  7.342394
# 1281194  Course de l'Escalade, Genève  sam. 05.12.2015  2.340375
#
#                        Name Sex  Year   LivingPlace  Rank       Time  \
# 1281190        Zwahlen Guy    M  1959        Genève   920  0:42.25,8
# 1281191    Zwahlen Laurent    M  1967       Concise  1417  0:37.43,4
# 1281192  Zweigart Benjamin    M  1991     Confignon   357   0:31.8,2
# 1281193      Zwicky Pierre    M  1963        Genève  1089   0:45.2,1
# 1281194    Zwimpfer Maxime    M  2005   Vandoeuvres   223   0:11.7,7
#
#              Delay                       ...                       uv_index  \
# 1281190   0:17.0,2                       ...                            0.0
# 1281191  0:13.27,1                       ...                            0.0
# 1281192   0:7.20,9                       ...                            0.0
# 1281193  0:18.21,8                       ...                            0.0
# 1281194   0:2.52,1                       ...                            0.0
#
#          weather_desc   latitude  longitude   weekday  day  month    year  \
# 1281190         Sunny  46.204391   6.143158  saturday  5.0   12.0  2015.0
# 1281191         Sunny  46.204391   6.143158  saturday  5.0   12.0  2015.0
# 1281192         Sunny  46.204391   6.143158  saturday  5.0   12.0  2015.0
# 1281193         Sunny  46.204391   6.143158  saturday  5.0   12.0  2015.0
# 1281194         Sunny  46.204391   6.143158  saturday  5.0   12.0  2015.0
#
#          time                                      race_index
# 1281190  2545  Course de l'Escalade, Genève ; sam. 05.12.2015
# 1281191  2263  Course de l'Escalade, Genève ; sam. 05.12.2015
# 1281192  1868  Course de l'Escalade, Genève ; sam. 05.12.2015
# 1281193  2702  Course de l'Escalade, Genève ; sam. 05.12.2015
# 1281194   667  Course de l'Escalade, Genève ; sam. 05.12.2015
#
# [5 rows x 24 columns]

# %% [markdown]
# # Aggregation by race

# %%
df.columns
# Out:
# Index(['Race', 'Date', 'Distance', 'Name', 'Sex', 'Year', 'LivingPlace',
#        'Rank', 'Time', 'Delay', 'Pace', 'len_name', 'min_temp', 'max_temp',
#        'uv_index', 'weather_desc', 'latitude', 'longitude', 'weekday', 'day',
#        'month', 'year', 'time', 'race_index'],
#       dtype='object')

# %%
def keep_first(x):
    return x.unique()[0]

def str_count(x, s=''):
    try:
        count = x.value_counts()[s]
    except KeyError:
        count = 0
    return count

aggregations = {
    'Race': {'race': keep_first},
    'Date': {'date': keep_first},
    'Distance': 'max',
    'Name': 'count',
    'Sex': {
        'M': lambda x: str_count(x, s='M'),
        'F': lambda x: str_count(x, s='F')
    },
    'Year': {
        'min_year': 'min', 
        'max_year': 'max',
        'mean_year': 'mean',
        'median_year': 'median'
    },
    'time': {
        'min_time': lambda x: seconds_to_time(x.min()),
        'max_time': lambda x: seconds_to_time(x.max()),
        'mean_time': lambda x: seconds_to_time(x.mean()),
        'median_time': lambda x: seconds_to_time(x.median()),
    },
    'latitude': {'latitude': keep_first},
    'longitude': {'longitude': keep_first},
    'weather_desc': {'weather_desc': keep_first},
    'min_temp': {'min_temp': keep_first},
    'max_temp': {'max_temp': keep_first},
}

# ---- INTERLUDE ----
#
# Not sure what's best here :
# - groupby 'race_index' and export all data in one huge JSON file (choice 1)
# - groupby ['Race', 'Date'] and export one JSON file by race name (choice 2)
#
# Maybe choice 2 is more practical when working with D3 / viz tools...
# -------------------

races_stats = df.groupby('race_index').agg(aggregations)     # choice 1
# races_stats = df.groupby(['Race', 'Date']).agg(aggregations) # choice 2

races_stats.columns = races_stats.columns.droplevel(0)

# %%
races_stats.head()
# Out:
#                                                       median_time min_time  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...  0.0:42.0:29.0  0:22:15
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...  0.0:41.0:24.0  0:17:23
# 10km de Payerne ; sam. 27.03.2010                   0.0:38.0:58.0   0:1:23
# 10km de Payerne ; sam. 28.03.2009                   0.0:41.0:18.0  0:29:55
# 10km, Payerne ; sam. 10.03.2012                     0.0:42.0:50.0   0:1:26
#
#                                                    max_time  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...  1:15:56
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...  1:15:57
# 10km de Payerne ; sam. 27.03.2010                   1:28:14
# 10km de Payerne ; sam. 28.03.2009                   1:27:13
# 10km, Payerne ; sam. 10.03.2012                     1:14:23
#
#                                                                       mean_time  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...   0.0:43.0:42.61190965092419
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...   0.0:42.0:26.39381443298953
# 10km de Payerne ; sam. 27.03.2010                   0.0:35.0:24.844331641285862
# 10km de Payerne ; sam. 28.03.2009                    0.0:43.0:15.14673913043498
# 10km, Payerne ; sam. 10.03.2012                     0.0:38.0:23.193430656934197
#
#                                                       F    M  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...  130  357
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...  115  370
# 10km de Payerne ; sam. 27.03.2010                   188  403
# 10km de Payerne ; sam. 28.03.2009                    80  288
# 10km, Payerne ; sam. 10.03.2012                     140  408
#
#                                                                                    race  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...  10km Schweizer Meisterschaften Lyss
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...  10km Schweizer Meisterschaften Lyss
# 10km de Payerne ; sam. 27.03.2010                                       10km de Payerne
# 10km de Payerne ; sam. 28.03.2009                                       10km de Payerne
# 10km, Payerne ; sam. 10.03.2012                                           10km, Payerne
#
#                                                                date   max  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...  sam. 02.04.2011  10.0
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...  sam. 31.03.2012  10.0
# 10km de Payerne ; sam. 27.03.2010                   sam. 27.03.2010  10.0
# 10km de Payerne ; sam. 28.03.2009                   sam. 28.03.2009  10.0
# 10km, Payerne ; sam. 10.03.2012                     sam. 10.03.2012  10.0
#
#                                                      latitude  min_year  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...  47.074650      1923
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...  47.074650      1934
# 10km de Payerne ; sam. 27.03.2010                   46.822027      1923
# 10km de Payerne ; sam. 28.03.2009                   46.822027      1923
# 10km, Payerne ; sam. 10.03.2012                     46.822027      1943
#
#                                                     max_year    mean_year  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...      1997  1966.012320
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...      1998  1966.777320
# 10km de Payerne ; sam. 27.03.2010                       2007  1974.335025
# 10km de Payerne ; sam. 28.03.2009                       1995  1964.978261
# 10km, Payerne ; sam. 10.03.2012                         2010  1976.005474
#
#                                                     median_year  min_temp  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...       1965.0       6.0
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...       1966.0       4.0
# 10km de Payerne ; sam. 27.03.2010                        1971.0       0.0
# 10km de Payerne ; sam. 28.03.2009                        1966.0       2.0
# 10km, Payerne ; sam. 10.03.2012                          1973.0      -5.0
#
#                                                     max_temp  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...      25.0
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...      15.0
# 10km de Payerne ; sam. 27.03.2010                       10.0
# 10km de Payerne ; sam. 28.03.2009                        5.0
# 10km, Payerne ; sam. 10.03.2012                          8.0
#
#                                                             weather_desc  \
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...                 Clear
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...                Cloudy
# 10km de Payerne ; sam. 27.03.2010                   Patchy rain possible
# 10km de Payerne ; sam. 28.03.2009                          Partly cloudy
# 10km, Payerne ; sam. 10.03.2012                                    Sunny
#
#                                                     longitude  count
# race_index
# 10km Schweizer Meisterschaften Lyss ; sam. 02.0...   7.307702    487
# 10km Schweizer Meisterschaften Lyss ; sam. 31.0...   7.307702    485
# 10km de Payerne ; sam. 27.03.2010                    6.940566    591
# 10km de Payerne ; sam. 28.03.2009                    6.940566    368
# 10km, Payerne ; sam. 10.03.2012                      6.940566    548

# %%
# Example of JSON export
races_stats[:2].to_json(orient='index')
# Out:
# '{"10km Schweizer Meisterschaften Lyss ; sam. 02.04.2011":{"median_time":"0.0:42.0:29.0","min_time":"0:22:15","max_time":"1:15:56","mean_time":"0.0:43.0:42.61190965092419","F":130,"M":357,"race":"10km Schweizer Meisterschaften Lyss","date":"sam. 02.04.2011","max":10.0,"latitude":47.0746504,"min_year":1923,"max_year":1997,"mean_year":1966.0123203285,"median_year":1965.0,"min_temp":6.0,"max_temp":25.0,"weather_desc":"Clear","longitude":7.3077022,"count":487},"10km Schweizer Meisterschaften Lyss ; sam. 31.03.2012":{"median_time":"0.0:41.0:24.0","min_time":"0:17:23","max_time":"1:15:57","mean_time":"0.0:42.0:26.39381443298953","F":115,"M":370,"race":"10km Schweizer Meisterschaften Lyss","date":"sam. 31.03.2012","max":10.0,"latitude":47.0746504,"min_year":1934,"max_year":1998,"mean_year":1966.7773195876,"median_year":1966.0,"min_temp":4.0,"max_temp":15.0,"weather_desc":"Cloudy","longitude":7.3077022,"count":485}}'

# %%
races_stats.to_json('races.json', orient='index')

# %% [markdown]
# **SOME COMMENTS FOR LATER**
#
# * When aggregating, we should compute more detailed things, eg. time/gender, etc... to have something nice to visualize on the details page using D3.js

# %% [markdown]
# # Aggregation by name
#
# **TO DO ! Beware of the name 'real' duplicates (two different persons with same name (and sometimes same birthyear...)), and the 'false' duplicates (different formatting for the same name, eg. trailing space).**

# %%
df.Name.value_counts().head()
# Out:
# Schmid Christian     180
# Meier Thomas         170
# Müller Martin        160
# Müller Thomas        155
# Meier Andreas        136
# Name: Name, dtype: int64

# %%
name_agg_df = df[df.Name.str.strip() == 'Schmid Christian']

# %%
name_agg_df.head()
# Out:
#                                Race             Date  Distance  \
# 2304  Jungfrau-Marathon, Interlaken  sam. 06.09.2003    42.195
# 2305  Jungfrau-Marathon, Interlaken  sam. 06.09.2003    42.195
# 2306  Jungfrau-Marathon, Interlaken  sam. 06.09.2003    42.195
# 5569  Jungfrau-Marathon, Interlaken  sam. 11.09.2004    42.195
# 9147  Jungfrau-Marathon, Interlaken  sam. 10.09.2005    42.195
#
#                    Name Sex  Year    LivingPlace  Rank       Time      Delay  \
# 2304  Schmid Christian    M  1981   DE-Waldbronn   332  4:38.55,9  1:49.54,3
# 2305  Schmid Christian    M  1967        Berikon   160  4:12.29,0  1:23.27,4
# 2306  Schmid Christian    M  1963     Morrens VD   397  5:15.51,2  1:52.59,6
# 5569  Schmid Christian    M  1967        Berikon   183  4:16.34,4   1:17.3,5
# 9147  Schmid Christian    M  1968         Zürich   270  4:29.35,3  1:30.13,5
#
#           Pace  len_name   time  \
# 2304  0:6.36,0         2  16735
# 2305  0:5.59,0         2  15149
# 2306  0:7.29,0         2  18951
# 5569   0:6.4,0         2  15394
# 9147  0:6.23,0         2  16175
#
#                                            race_index
# 2304  Jungfrau-Marathon, Interlaken ; sam. 06.09.2003
# 2305  Jungfrau-Marathon, Interlaken ; sam. 06.09.2003
# 2306  Jungfrau-Marathon, Interlaken ; sam. 06.09.2003
# 5569  Jungfrau-Marathon, Interlaken ; sam. 11.09.2004
# 9147  Jungfrau-Marathon, Interlaken ; sam. 10.09.2005
